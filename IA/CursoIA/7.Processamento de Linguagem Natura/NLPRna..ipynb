# %%
import pandas as pd
import numpy as np
import random

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.layers import Input, Embedding, Flatten, Dense, Dropout
from tensorflow.keras.models import Model

# %%
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)

# %%
spam = pd.read_csv('spam.csv')
spam.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
spam.shape
# Out:
# (5572, 2)

# %%
count = spam['Category'].value_counts()
print(count)
# Out:
# Category
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
ham_samples = spam[spam["Category"]=='ham'].sample(n=747, random_state=42)
spam_samples = spam[spam["Category"]=='spam']

spam = pd.concat([ham_samples,spam_samples]).sample(frac=1, random_state=42).reset_index(drop=True)

# %%
spam.shape
# Out:
# (1494, 2)

# %%
labelencoder = LabelEncoder()
y = labelencoder.fit_transform(spam["Category"])

# %%
y
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
mensagens = spam['Message'].values
X_train, X_test, y_train, y_test = train_test_split(mensagens, y, test_size=0.3, random_state=43)

# %%
token = Tokenizer(num_words=1000)
token.fit_on_texts(X_train)
X_train = token.texts_to_sequences(X_train)
X_test = token.texts_to_sequences(X_test)

# %%
print(X_train)
# Out:
# [[404, 404, 101, 11, 46, 880], [702, 702, 102, 453, 1, 5, 87, 2, 302, 22, 302], [610, 881, 83, 87, 48, 2, 77, 22, 1, 148, 453], [256, 36, 8, 60, 22], [50, 272, 1, 80, 2, 362, 7, 1, 43, 192, 21, 3, 51, 58, 882, 12, 273, 883, 32, 15, 6, 274, 9, 193], [204, 129, 13, 35, 20, 405, 257, 21, 454, 231, 28, 114, 1, 510, 10, 275, 511, 276, 27, 71, 107, 884, 277, 363, 406, 88, 19, 278, 15, 29], [139, 407, 6, 885, 1, 35, 7, 81, 124, 53, 15, 205, 303, 304, 1, 3, 149, 337, 10], [4, 125, 112, 703, 455, 338, 21, 886, 16, 102, 1, 704, 4, 102, 3, 887, 305, 170, 304, 306, 888, 21, 84], [232, 217, 4, 218, 705, 21, 12], [150, 206, 408, 51, 456, 364, 1, 7, 27, 126, 61], [22, 13, 307, 4, 512, 5, 409, 33, 115, 46, 889, 308, 96, 47, 8], [10, 19, 410, 15, 20, 171, 457, 411, 410, 108, 1, 184, 1, 339, 12, 30], [154, 34, 17, 11, 17, 52, 233, 340, 11, 155, 52, 116, 46, 4, 185, 2, 3, 194, 67, 2, 309, 5, 458, 97, 341, 170, 9, 5], [172, 611, 4, 18, 1], [20, 53, 513, 11, 514, 207, 310, 1, 706, 20, 53, 17, 10, 44, 53, 1, 258, 37, 65, 74, 890, 459, 342, 343, 344, 515], [516, 33, 365, 460, 68, 707, 171, 708], [307, 8, 77, 22, 116, 8, 517, 311, 12, 18, 3, 518, 26, 412, 3, 891, 82, 23, 3, 259, 101, 115, 50, 62, 208, 19, 413], [46, 8, 312, 47, 309, 20, 892], [172, 2, 60, 709, 23, 37, 72, 73], [14, 234, 150, 406, 1, 186, 150, 30, 173, 61, 14, 44, 893, 1, 894, 130, 92, 61, 29, 117, 710], [170, 9, 7, 150, 366, 2, 42, 38, 461, 895, 26, 92, 61, 2, 60, 345, 56, 367, 68, 519, 109, 368, 16], [104, 36, 18, 106, 612, 520, 1, 48, 414, 38, 17, 613, 219], [30, 5, 103, 407, 13, 20, 27, 63, 131, 14, 415, 3, 14, 89, 19, 521, 16, 1, 184, 39, 462, 78, 
X_train = pad_sequences(X_train, padding='post', maxlen=500)
X_test  = pad_sequences(X_test, padding='post', maxlen=500)

# %%
input_layer = Input(shape=(500,))
embedding_layer = Embedding(input_dim=len(token.word_index), output_dim=50)(input_layer)
flatten_layer = Flatten()(embedding_layer)
dense_layer = Dense(units=10, activation='relu')(flatten_layer)
dropout_layer = Dropout(0.1)(dense_layer)
output_layer = Dense(units=1, activation='sigmoid')(dropout_layer)
modelo = Model(inputs=input_layer, outputs=output_layer)

# %%
modelo.compile(loss='mean_squared_error', optimizer='adam', metrics=["accuracy"])

# %%
modelo.fit(X_train, y_train, epochs=20, batch_size=10, verbose=True, validation_data=(X_test,y_test))
# Out:
# Epoch 1/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5944 - loss: 0.2463 - val_accuracy: 0.8285 - val_loss: 0.1612
# Epoch 2/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8213 - loss: 0.1251 - val_accuracy: 0.9220 - val_loss: 0.0724
# Epoch 3/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8996 - loss: 0.0721 - val_accuracy: 0.9555 - val_loss: 0.0480
# Epoch 4/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9262 - loss: 0.0489 - val_accuracy: 0.9688 - val_loss: 0.0369
# Epoch 5/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9126 - loss: 0.0465 - val_accuracy: 0.9688 - val_loss: 0.0343
# Epoch 6/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9392 - loss: 0.0395 - val_accuracy: 0.9666 - val_loss: 0.0323
# Epoch 7/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9418 - loss: 0.0391 - val_accuracy: 0.9666 - val_loss: 0.0295
# Epoch 8/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9692 - loss: 0.0230 - val_accuracy: 0.9666 - val_loss: 0.0298
# Epoch 9/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9834 - loss: 0.0197 - val_accuracy: 0.9599 - val_loss: 0.0312
# Epoch 10/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9784 - loss: 0.0206 - val_accuracy: 0.9666 - val_loss: 0.0267
# Epoch 11/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9910 - loss: 0.0181 - val_accuracy: 0.9688 - val_loss: 0.0264
# Epoch 12/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9870 - loss: 0.0185 - val_accuracy: 0.9710 - val_loss: 0.0254
# Epoch 13/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9903 - loss: 0.0141 - val_accuracy: 0.9710 - val_loss: 0.0258
# Epoch 14/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9949 - loss: 0.0152 - val_accuracy: 0.9688 - val_loss: 0.0271
# Epoch 15/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9884 - loss: 0.0139 - val_accuracy: 0.9688 - val_loss: 0.0267
# Epoch 16/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9942 - loss: 0.0149 - val_accuracy: 0.9644 - val_loss: 0.0269
# Epoch 17/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9965 - loss: 0.0143 - val_accuracy: 0.9710 - val_loss: 0.0256
# Epoch 18/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9945 - loss: 0.0091 - val_accuracy: 0.9688 - val_loss: 0.0260
# Epoch 19/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9971 - loss: 0.0083 - val_accuracy: 0.9666 - val_loss: 0.0267
# Epoch 20/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9940 - loss: 0.0106 - val_accuracy: 0.9621 - val_loss: 0.0297

# %%
loss, accuracy = modelo.evaluate(X_test, y_test)
print("Loss: ", loss)
print("Acurácia: ", accuracy)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9556 - loss: 0.0330
# Loss:  0.02971014752984047
# Acurácia:  0.9621380567550659

# %%
nova_previsao = modelo.predict(X_test)
print(nova_previsao[2:5])
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# [[0.99242294]
#  [0.01563588]
#  [0.00687532]]

# %%
prev = (nova_previsao > 0.5 )
print(prev[2:5])
# Out:
# [[ True]
#  [False]
#  [False]]

# %%
cm = confusion_matrix(y_test, prev)
print(cm)
# Out:
# [[225   7]
#  [ 10 207]]
