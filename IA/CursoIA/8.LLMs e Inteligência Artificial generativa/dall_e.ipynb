# %%
# !pip install openai

# %%
from openai import OpenAI
from PIL import Image
import base64
import requests
from io import BytesIO
from IPython.display import display

# %%
client = OpenAI(api_key="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")

# %%
response = client.images.generate(
    model = 'dall-e-3',
    prompt = "Centro de controle futurista com hologramas e vista para uma cidade cyberpunk",
    size = "1024x1024",
    quality="standard", #hd
    n=1
)

# %%
image_url = response.data[0].url
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-GG4FgdsC7pjFXZUzJaf0Lg0F/user-EKimdtZ0sFPHREewg6LEw2r4/img-vC1206A8xVOq6IC1Jq6iBMA1.png?st=2025-04-10T22%3A10%3A26Z&se=2025-04-11T00%3A10%3A26Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-04-10T20%3A55%3A03Z&ske=2025-04-11T20%3A55%3A03Z&sks=b&skv=2024-08-04&sig=ReH7H%2BQcZgURHRWQWGinf2iLyfK8OKFI82h%2Bxg1Acn0%3D

# %%
image_response = requests.get(image_url)
img = Image.open(BytesIO(image_response.content))
display(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
response = client.images.generate(
    model = 'dall-e-3',
    prompt = "Robô antigo empoeirado sentando em uma oficina abandonada",
    size = "1792x1024",
    quality="standard", #hd
    n=1,
    response_format="b64_json"
)

# %%
imagem_b64 = response.data[0].b64_json
imagem = base64.b64decode(imagem_b64)

# %%
with open("robo.png","wb") as f:
  f.write(imagem)

display(Image.open("robo.png"))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
