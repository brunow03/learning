# %%
from sklearn import datasets
import numpy as np
from sklearn.preprocessing import scale
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
from hopkins import *
from metric import *
from visual_assessment_of_tendency import *

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
iris = datasets.load_iris()
clust1 = scale(iris.data)
clust2 = scale(np.random.rand(150,4))

# %%
print(clust2)
# Out:
# [[ 1.45054071  0.18627295  0.70066433  0.17640979]
#  [ 1.07420772  0.75622451  0.46799331 -0.94655096]
#  [ 1.22847956 -0.09332025  1.4989425  -0.84592384]
#  [ 0.09494145  1.18388947 -0.64170405 -0.24158422]
#  [-0.05379408  1.65085538  1.65329098  0.61370638]
#  [-1.402423    1.14048661 -1.31036607  0.78540202]
#  [-0.99295614 -0.02035814 -0.88105915 -0.19000768]
#  [ 1.39398546 -0.88627548 -0.22618623  0.71633714]
#  [ 0.48126832 -1.35257645  0.93791943  0.8732632 ]
#  [-0.74709117  0.89364408  1.81617655  0.1530173 ]
#  [ 1.00522123  0.6245248   0.90165898  1.49435308]
#  [ 1.19826966 -1.11672764 -1.17769328 -1.53599686]
#  [-0.65823658 -1.0734169   1.88749544  0.04560461]
#  [-1.53221116 -1.1381286   0.62796646  0.14991655]
#  [ 1.47963213  1.36045953 -0.99675267 -1.55525868]
#  [ 1.19027503  1.10261445  0.61393992 -0.81175639]
#  [-0.90149307 -0.37184418 -1.26002887 -0.67022883]
#  [ 1.16665983 -1.13844957 -0.51834124 -0.94272993]
#  [-0.39816431 -0.54197802 -0.3943498  -1.59431224]
#  [ 0.67619842 -1.23515971 -0.83474024  1.4761688 ]
#  [-1.62486141  0.74995838 -0.79164493 -0.18140324]
#  [-0.31728726  0.39102175  0.84171338 -0.98362181]
#  [-1.10930584 -1.44372293  0.54322392  0.72750063]
#  [ 0.71112834  0.68667837 -1.20744122  1.13676978]
#  [ 0.56357268  0.38236779  0.93195167 -0.6749475 ]
#  [-1.6735865  -0.07390487 -1.28101558  1.06175702]
#  [ 0.48001517  1.22416893  1.35066837  1.6394267 ]
#  [-0.47699265  0.9664724   1.20124128 -1.24431419]
#  [ 0.83542359 -0.21859496  1.81612706  0.1083956 ]
#  [-1.35699487 -0.43559188  0.21942854 -0.44059962]
#  [-1.65519556 -0.19280716  0.58614226  0.23363565]
#  [-1.18508918  0.52183892  0.59378204  1.73592638]
#  [-1.11944198  1.14768948  0.27083177 -1.00999971]
#  [ 0.28326562 -1.12792289 -1.02489658 -0.10292661]
#  [ 0.53656322  1.26744226 -1.41876585 -0.50927314]
#  [ 0.49532423  0.13397418 -0.45641171 -1.5822059 ]
#  [-1.07245977  1.33445438  0.54469134  1.28547685]
#  [ 1.2662522   0.65530859 -0.6221348   0.02297427]
#  [-0.8385609   1.08912157  0.45803277  1.00506157]
#  [ 0.23094828  0.96482866 -1.04925883  1.6931123 ]
#  [-1.60868     0.88030961  1.41509817  1.08947867]
#  [-1.19978352  0.39298075 -1.43035042  1.61794432]
#  [-1.32761457  0.39755773  1.5387762  -1.16283076]
#  [ 0.35724687  1.64336429 -1.56633901  1.45668333]
#  [-1.64981163 -1.50942363 -0.81013286 -1.50601949]
#  [ 0.86470977 -1.17105298  1.80707743  0.23617454]
#  [ 0.22294559 -1.57515259 -1.48960467 -0.737714  ]
#  [-1.65605131  0.93002181 -0.17912308  1.16817223]
#  [-0.03580677  0.02337706 -1.18694739  1.05722811]
#  [ 0.95368548 -0.96235584  0.28328132  0.45338068]
#  [-1.43046828  1.06110066 -1.6593105   1.57077794]
#  [-0.91048842 -0.46192045 -0.30827738 -1.63412305]
#  [ 1.43207671  1.59562593  0.28012666 -1.41898002]
#  [-0.26756451 -0.9393058   0.29202745  1.37374603]
#  [-1.08147282 -0.20614283 -0.77397295  1.60596276]
#  [ 0.76593648  1.4700809   0.04259481  1.0457211 ]
#  [ 0.09558391 -1.34901578  0.20706186  0.17356538]
#  [-1.04814246 -0.7068562  -0.95797016 -0.97928182]
#  [ 0.56921012 -0.1919826   1.67642206 -1.63850379]
#  [-1.6543171  -1.13917775 -0.20643785  0.78596904]
#  [-1.58373938 -0.42139854  0.61613682  1.14995941]]

# %%
inertia = []
for i in range(1,8):
  kmeans = KMeans(n_clusters=i, n_init='auto')
  kmeans.fit(clust1)
  inertia.append(kmeans.inertia_)
plt.plot(range(1,8), inertia)
plt.title("Elbow")
plt.show()

# %%
inertia = []
for i in range(1,8):
  kmeans = KMeans(n_clusters=i, n_init='auto')
  kmeans.fit(clust2)
  inertia.append(kmeans.inertia_)
plt.plot(range(1,8), inertia)
plt.title("Elbow")
plt.show()

# %%
hopkins(clust1,150)
# Out:
# np.float64(0.17696183482169345)

# %%
hopkins(clust2,150)
# Out:
# np.float64(0.5271045789456987)

# %%
vat(clust1)

# %%
vat(clust2)

# %%
ivat(clust1)

# %%
ivat(clust2)

# %%
#m = assess_tendency_by_metric(clust1,'silhouette',5)
#m = assess_tendency_by_metric(clust1,'davies_bouldin',5)
m = assess_tendency_by_metric(clust1,'calinski_harabasz',5)
print(m)
# Out:
# (np.int64(2), array([251.34933946, 241.9044017 , 205.40053907, 170.17295119]))

# %%
#m = assess_tendency_by_metric(clust2,'silhouette',5)
#m = assess_tendency_by_metric(clust2,'davies_bouldin',5)
m = assess_tendency_by_metric(clust2,'calinski_harabasz',5)
print(m)
# Out:
# (np.int64(5), array([34.12207174, 32.0625277 , 37.9673355 , 40.3584992 ]))

# %%
m = assess_tendency_by_mean_metric_score(clust1,5)
print(m)
# Out:
# 2.0

# %%
m = assess_tendency_by_mean_metric_score(clust2,5)
print(m)
# Out:
# 5.0
