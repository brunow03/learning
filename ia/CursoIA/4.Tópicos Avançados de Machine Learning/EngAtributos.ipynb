# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
dataset = pd.read_csv('credit_simple.csv', sep=';')
dataset.shape
# Out:
# (1000, 8)

# %%
dataset.head()
# Out:
#    SALDO_ATUAL  RESIDENCIADESDE  IDADE OUTROSPLANOSPGTO        DATA  \
# 0       1169.0                4     67           nenhum  01/01/2019
# 1       5951.0                2     22           nenhum  01/01/2020
# 2       2096.0                3     49           nenhum  02/01/2020
# 3       7882.0                4     45           nenhum  02/01/2019
# 4       4870.0                4     53           nenhum  03/01/2018
#
#           ESTADOCIVIL            PROPOSITO CLASSE
# 0  masculino solteiro             radio/tv    bom
# 1         fem div/cas             radio/tv   ruim
# 2  masculino solteiro             educação    bom
# 3  masculino solteiro  mobilia/equipamento    bom
# 4  masculino solteiro           carro novo   ruim

# %%
y = dataset['CLASSE']
X = dataset.iloc[:,:-1]

# %%
X.isnull().sum()
# Out:
# SALDO_ATUAL         7
# RESIDENCIADESDE     0
# IDADE               0
# OUTROSPLANOSPGTO    0
# DATA                0
# ESTADOCIVIL         8
# PROPOSITO           0
# dtype: int64

# %%
mediana = X['SALDO_ATUAL'].median()
mediana
# Out:
# np.float64(2323.0)

# %%
X['SALDO_ATUAL'].fillna(mediana,inplace=True)
X.isnull().sum()
# Out:
# /tmp/ipykernel_34059/2913618785.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   X['SALDO_ATUAL'].fillna(mediana,inplace=True)
# SALDO_ATUAL         7
# RESIDENCIADESDE     0
# IDADE               0
# OUTROSPLANOSPGTO    0
# DATA                0
# ESTADOCIVIL         8
# PROPOSITO           0
# dtype: int64

# %%
agrupado = X.groupby(['ESTADOCIVIL']).size()
agrupado
# Out:
# ESTADOCIVIL
# fem div/cas               308
# masculino casado/viuvo     92
# masculino div/sep          50
# masculino solteiro        542
# dtype: int64

# %%
X['ESTADOCIVIL'].fillna('masculino solteiro', inplace=True)
X.isnull().sum()
# Out:
# /tmp/ipykernel_34059/1274388989.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   X['ESTADOCIVIL'].fillna('masculino solteiro', inplace=True)
# SALDO_ATUAL         7
# RESIDENCIADESDE     0
# IDADE               0
# OUTROSPLANOSPGTO    0
# DATA                0
# ESTADOCIVIL         8
# PROPOSITO           0
# dtype: int64

# %%
desv = X['SALDO_ATUAL'].std()
desv
# Out:
# np.float64(688349579.4790443)

# %%
X.loc[X['SALDO_ATUAL']>= 2 * desv, 'SALDO_ATUAL']
# Out:
# 127    2.541111e+09
# 160    2.154441e+10
# Name: SALDO_ATUAL, dtype: float64

# %%
mediana = X['SALDO_ATUAL'].median()
mediana
# Out:
# np.float64(2323.0)

# %%
X.loc[X['SALDO_ATUAL']>= 2 * desv, 'SALDO_ATUAL'] = mediana
X.loc[X['SALDO_ATUAL']>= 2 * desv]
# Out:
# Empty DataFrame
# Columns: [SALDO_ATUAL, RESIDENCIADESDE, IDADE, OUTROSPLANOSPGTO, DATA, ESTADOCIVIL, PROPOSITO]
# Index: []

# %%
agrupado = X.groupby(['PROPOSITO']).size()
agrupado
# Out:
# PROPOSITO
# Eletrodomésticos        12
# carro novo             234
# carro usado            103
# educação                50
# mobilia/equipamento    181
# negócios                97
# obras                   22
# outros                  12
# qualificação             9
# radio/tv               280
# dtype: int64

# %%
X.loc[X['PROPOSITO']=='Eletrodomésticos','PROPOSITO'] = 'outros'
X.loc[X['PROPOSITO']=='qualificação','PROPOSITO'] = 'outros'
agrupado = X.groupby(['PROPOSITO']).size()
agrupado
# Out:
# PROPOSITO
# carro novo             234
# carro usado            103
# educação                50
# mobilia/equipamento    181
# negócios                97
# obras                   22
# outros                  33
# radio/tv               280
# dtype: int64

# %%
X['DATA']
# Out:
# 0      01/01/2019
# 1      01/01/2020
# 2      02/01/2020
# 3      02/01/2019
# 4      03/01/2018
#           ...
# 995    29/06/2018
# 996    30/06/2018
# 997    03/07/2018
# 998    04/07/2019
# 999    05/07/2018
# Name: DATA, Length: 1000, dtype: str

# %%
X['DATA'] = pd.to_datetime(X['DATA'], format='%d/%m/%Y')

# %%
X['DATA']
# Out:
# 0     2019-01-01
# 1     2020-01-01
# 2     2020-01-02
# 3     2019-01-02
# 4     2018-01-03
#          ...
# 995   2018-06-29
# 996   2018-06-30
# 997   2018-07-03
# 998   2019-07-04
# 999   2018-07-05
# Name: DATA, Length: 1000, dtype: datetime64[us]

# %%
X['ANO'] = X['DATA'].dt.year
X['MES'] = X['DATA'].dt.month
X['DIASEMANA'] = X['DATA'].dt.day_name()

# %%
X['DIASEMANA']
# Out:
# 0        Tuesday
# 1      Wednesday
# 2       Thursday
# 3      Wednesday
# 4      Wednesday
#          ...
# 995       Friday
# 996     Saturday
# 997      Tuesday
# 998     Thursday
# 999     Thursday
# Name: DIASEMANA, Length: 1000, dtype: str

# %%
X['ESTADOCIVIL'].unique()
# Out:
# <StringArray>
# [    'masculino solteiro',            'fem div/cas',      'masculino div/sep',
#  'masculino casado/viuvo',                      nan]
# Length: 5, dtype: str

# %%
X['PROPOSITO'].unique()
# Out:
# <StringArray>
# [           'radio/tv',            'educação', 'mobilia/equipamento',
#           'carro novo',         'carro usado',            'negócios',
#               'outros',               'obras']
# Length: 8, dtype: str

# %%
X['DIASEMANA'].unique()
# Out:
# <StringArray>
# ['Tuesday', 'Wednesday', 'Thursday', 'Saturday', 'Sunday', 'Monday', 'Friday']
# Length: 7, dtype: str

# %%
labelencoder1 = LabelEncoder()
X['ESTADOCIVIL'] = labelencoder1.fit_transform(X['ESTADOCIVIL'])
X['PROPOSITO'] = labelencoder1.fit_transform(X['PROPOSITO'])
X['DIASEMANA'] = labelencoder1.fit_transform(X['DIASEMANA'])

# %%
X.head()
# Out:
#    SALDO_ATUAL  RESIDENCIADESDE  IDADE OUTROSPLANOSPGTO       DATA  \
# 0       1169.0                4     67           nenhum 2019-01-01
# 1       5951.0                2     22           nenhum 2020-01-01
# 2       2096.0                3     49           nenhum 2020-01-02
# 3       7882.0                4     45           nenhum 2019-01-02
# 4       4870.0                4     53           nenhum 2018-01-03
#
#    ESTADOCIVIL  PROPOSITO   ANO  MES  DIASEMANA
# 0            3          7  2019    1          5
# 1            0          7  2020    1          6
# 2            3          2  2020    1          4
# 3            3          3  2019    1          6
# 4            3          0  2018    1          6

# %%
outros = X['OUTROSPLANOSPGTO'].unique()
outros
# Out:
# <StringArray>
# ['nenhum', 'banco', 'stores']
# Length: 3, dtype: str

# %%
z = pd.get_dummies(X['OUTROSPLANOSPGTO'], prefix = 'OUTROS')

# %%
z
# Out:
#      OUTROS_banco  OUTROS_nenhum  OUTROS_stores
# 0           False           True          False
# 1           False           True          False
# 2           False           True          False
# 3           False           True          False
# 4           False           True          False
# ..            ...            ...            ...
# 995         False           True          False
# 996         False           True          False
# 997         False           True          False
# 998         False           True          False
# 999         False           True          False
#
# [1000 rows x 3 columns]

# %%
X
# Out:
#      SALDO_ATUAL  RESIDENCIADESDE  IDADE OUTROSPLANOSPGTO       DATA  \
# 0         1169.0                4     67           nenhum 2019-01-01
# 1         5951.0                2     22           nenhum 2020-01-01
# 2         2096.0                3     49           nenhum 2020-01-02
# 3         7882.0                4     45           nenhum 2019-01-02
# 4         4870.0                4     53           nenhum 2018-01-03
# ..           ...              ...    ...              ...        ...
# 995       1736.0                4     31           nenhum 2018-06-29
# 996       3857.0                4     40           nenhum 2018-06-30
# 997        804.0                4     38           nenhum 2018-07-03
# 998       1845.0                4     23           nenhum 2019-07-04
# 999       4576.0                4     27           nenhum 2018-07-05
#
#      ESTADOCIVIL  PROPOSITO   ANO  MES  DIASEMANA
# 0              3          7  2019    1          5
# 1              0          7  2020    1          6
# 2              3          2  2020    1          4
# 3              3          3  2019    1          6
# 4              3          0  2018    1          6
# ..           ...        ...   ...  ...        ...
# 995            0          3  2018    6          0
# 996            2          1  2018    6          2
# 997            3          7  2018    7          5
# 998            3          7  2019    7          4
# 999            3          1  2018    7          4
#
# [1000 rows x 10 columns]

# %%
sc = StandardScaler()
m = sc.fit_transform(X.iloc[:,0:3])
m
# Out:
# array([[-0.74554622,  1.04698668,  1.6392759 ],
#        [ 0.95240842, -0.76597727, -0.74024139],
#        [-0.41639441,  0.14050471,  0.68746898],
#        ...,
#        [-0.87514753,  1.04698668,  0.1058092 ],
#        [-0.5055175 ,  1.04698668, -0.68736323],
#        [ 0.46418432,  1.04698668, -0.47585058]], shape=(1000, 3))

# %%
X = pd.concat([X,z,pd.DataFrame(m,columns=['SALDO_ATUAL_N','RESIDENCEADESDE_N','IDADE_N'])],axis=1)

# %%
X.head()
# Out:
#    SALDO_ATUAL  RESIDENCIADESDE  IDADE OUTROSPLANOSPGTO       DATA  \
# 0       1169.0                4     67           nenhum 2019-01-01
# 1       5951.0                2     22           nenhum 2020-01-01
# 2       2096.0                3     49           nenhum 2020-01-02
# 3       7882.0                4     45           nenhum 2019-01-02
# 4       4870.0                4     53           nenhum 2018-01-03
#
#    ESTADOCIVIL  PROPOSITO   ANO  MES  DIASEMANA  OUTROS_banco  OUTROS_nenhum  \
# 0            3          7  2019    1          5         False           True
# 1            0          7  2020    1          6         False           True
# 2            3          2  2020    1          4         False           True
# 3            3          3  2019    1          6         False           True
# 4            3          0  2018    1          6         False           True
#
#    OUTROS_stores  SALDO_ATUAL_N  RESIDENCEADESDE_N   IDADE_N
# 0          False      -0.745546           1.046987  1.639276
# 1          False       0.952408          -0.765977 -0.740241
# 2          False      -0.416394           0.140505  0.687469
# 3          False       1.638053           1.046987  0.475956
# 4          False       0.568576           1.046987  0.898982

# %%
X.drop(columns=['SALDO_ATUAL','RESIDENCIADESDE','IDADE','OUTROSPLANOSPGTO','DATA','OUTROS_banco'], inplace=True)

# %%
X
# Out:
#      ESTADOCIVIL  PROPOSITO   ANO  MES  DIASEMANA  OUTROS_nenhum  \
# 0              3          7  2019    1          5           True
# 1              0          7  2020    1          6           True
# 2              3          2  2020    1          4           True
# 3              3          3  2019    1          6           True
# 4              3          0  2018    1          6           True
# ..           ...        ...   ...  ...        ...            ...
# 995            0          3  2018    6          0           True
# 996            2          1  2018    6          2           True
# 997            3          7  2018    7          5           True
# 998            3          7  2019    7          4           True
# 999            3          1  2018    7          4           True
#
#      OUTROS_stores  SALDO_ATUAL_N  RESIDENCEADESDE_N   IDADE_N
# 0            False      -0.745546           1.046987  1.639276
# 1            False       0.952408          -0.765977 -0.740241
# 2            False      -0.416394           0.140505  0.687469
# 3            False       1.638053           1.046987  0.475956
# 4            False       0.568576           1.046987  0.898982
# ..             ...            ...                ...       ...
# 995          False      -0.544220           1.046987 -0.264338
# 996          False       0.208888           1.046987  0.211566
# 997          False      -0.875148           1.046987  0.105809
# 998          False      -0.505518           1.046987 -0.687363
# 999          False       0.464184           1.046987 -0.475851
#
# [1000 rows x 10 columns]
