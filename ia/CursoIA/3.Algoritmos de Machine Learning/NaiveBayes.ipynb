# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from yellowbrick.classifier import ConfusionMatrix

# %%
base = pd.read_csv("insurance.csv", keep_default_na=False)
base.head()
# Out:
#    Unnamed: 0  GoodStudent         Age    SocioEcon RiskAversion VehicleYear  \
# 0           1        False       Adult        Prole  Adventurous       Older
# 1           2        False      Senior        Prole     Cautious     Current
# 2           3        False      Senior  UpperMiddle   Psychopath     Current
# 3           4        False  Adolescent       Middle       Normal       Older
# 4           5        False  Adolescent        Prole       Normal       Older
#
#   ThisCarDam RuggedAuto  Accident    MakeModel  ... HomeBase AntiTheft  \
# 0   Moderate   EggShell      Mild      Economy  ...     City     False
# 1       None   Football      None      Economy  ...     City      True
# 2       None   Football      None  FamilySedan  ...     City     False
# 3       None   EggShell      None      Economy  ...   Suburb     False
# 4   Moderate   Football  Moderate      Economy  ...     City     False
#
#    PropCost OtherCarCost  OtherCar   MedCost  Cushioning Airbag   ILiCost  \
# 0   TenThou     Thousand      True  Thousand        Poor  False  Thousand
# 1  Thousand     Thousand      True  Thousand        Good   True  Thousand
# 2  Thousand     Thousand     False  Thousand        Good   True  Thousand
# 3  Thousand     Thousand      True  Thousand        Fair  False  Thousand
# 4   TenThou     Thousand     False  Thousand        Fair  False  Thousand
#
#    DrivHist
# 0      Many
# 1      Zero
# 2       One
# 3      Zero
# 4      Many
#
# [5 rows x 28 columns]

# %%
base = base.drop(columns=['Unnamed: 0'])
base.head()
# Out:
#    GoodStudent         Age    SocioEcon RiskAversion VehicleYear ThisCarDam  \
# 0        False       Adult        Prole  Adventurous       Older   Moderate
# 1        False      Senior        Prole     Cautious     Current       None
# 2        False      Senior  UpperMiddle   Psychopath     Current       None
# 3        False  Adolescent       Middle       Normal       Older       None
# 4        False  Adolescent        Prole       Normal       Older   Moderate
#
#   RuggedAuto  Accident    MakeModel DrivQuality  ... HomeBase  AntiTheft  \
# 0   EggShell      Mild      Economy        Poor  ...     City      False
# 1   Football      None      Economy      Normal  ...     City       True
# 2   Football      None  FamilySedan   Excellent  ...     City      False
# 3   EggShell      None      Economy      Normal  ...   Suburb      False
# 4   Football  Moderate      Economy        Poor  ...     City      False
#
#    PropCost  OtherCarCost OtherCar   MedCost Cushioning Airbag   ILiCost  \
# 0   TenThou      Thousand     True  Thousand       Poor  False  Thousand
# 1  Thousand      Thousand     True  Thousand       Good   True  Thousand
# 2  Thousand      Thousand    False  Thousand       Good   True  Thousand
# 3  Thousand      Thousand     True  Thousand       Fair  False  Thousand
# 4   TenThou      Thousand    False  Thousand       Fair  False  Thousand
#
#   DrivHist
# 0     Many
# 1     Zero
# 2      One
# 3     Zero
# 4     Many
#
# [5 rows x 27 columns]

# %%
base.shape
# Out:
# (20000, 27)

# %%
print(base.isnull().sum())
# Out:
# GoodStudent     0
# Age             0
# SocioEcon       0
# RiskAversion    0
# VehicleYear     0
# ThisCarDam      0
# RuggedAuto      0
# Accident        0
# MakeModel       0
# DrivQuality     0
# Mileage         0
# Antilock        0
# DrivingSkill    0
# SeniorTrain     0
# ThisCarCost     0
# Theft           0
# CarValue        0
# HomeBase        0
# AntiTheft       0
# PropCost        0
# OtherCarCost    0
# OtherCar        0
# MedCost         0
# Cushioning      0
# Airbag          0
# ILiCost         0
# DrivHist        0
# dtype: int64

# %%
y = base.iloc[:,7].values
X  = base.drop(base.columns[7], axis=1).values
X
# Out:
# array([[False, 'Adult', 'Prole', ..., False, 'Thousand', 'Many'],
#        [False, 'Senior', 'Prole', ..., True, 'Thousand', 'Zero'],
#        [False, 'Senior', 'UpperMiddle', ..., True, 'Thousand', 'One'],
#        ...,
#        [False, 'Senior', 'UpperMiddle', ..., True, 'Thousand', 'Zero'],
#        [False, 'Adult', 'Middle', ..., True, 'Thousand', 'Zero'],
#        [False, 'Adult', 'Middle', ..., True, 'Thousand', 'Zero']],
#       shape=(20000, 26), dtype=object)

# %%
labelencoder = LabelEncoder()
for i in range(X.shape[1]):
  if X[:,i].dtype == 'object':
    X[:,i] = labelencoder.fit_transform(X[:,i])

# %%
X
# Out:
# array([[0, 1, 1, ..., 0, 3, 0],
#        [0, 2, 1, ..., 1, 3, 2],
#        [0, 2, 2, ..., 1, 3, 1],
#        ...,
#        [0, 2, 2, ..., 1, 3, 2],
#        [0, 1, 0, ..., 1, 3, 2],
#        [0, 1, 0, ..., 1, 3, 2]], shape=(20000, 26), dtype=object)

# %%
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(X,y,test_size=0.3, random_state=12)

# %%
modelo = GaussianNB()
modelo.fit(X_treinamento,y_treinamento)
# Out:
# GaussianNB()

# %%
previsoes = modelo.predict(X_teste)

# %%
previsoes
# Out:
# array(['Moderate', 'Mild', 'Moderate', ..., 'None', 'Mild', 'None'],
#       shape=(6000,), dtype='<U8')

# %%
accuracy = accuracy_score(y_teste,previsoes)
precision = precision_score(y_teste, previsoes, average='weighted')
recall = recall_score(y_teste, previsoes, average='weighted')
f1 = f1_score(y_teste, previsoes, average='weighted')
print(f'Acurácia: {accuracy}, Precisão: {precision}, Recall: {recall}, F1: {f1}')
# Out:
# Acurácia: 0.857, Precisão: 0.919107010136158, Recall: 0.857, F1: 0.8343753099843555

# %%
report = classification_report(y_teste, previsoes)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#         Mild       0.89      0.70      0.79       570
#     Moderate       0.38      0.91      0.54       488
#         None       0.98      1.00      0.99      4253
#       Severe       0.96      0.07      0.13       689
#
#     accuracy                           0.86      6000
#    macro avg       0.80      0.67      0.61      6000
# weighted avg       0.92      0.86      0.83      6000

# %%
confusion = ConfusionMatrix(modelo, classes=['None','Severe','Mild','Moderate'])
confusion.fit(X_treinamento, y_treinamento)
confusion.score(X_test,y_teste)
confusion.poof()
# Out:
# ---------------------------------------------------------------------------
# YellowbrickTypeError                      Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 confusion = ConfusionMatrix(modelo, classes=['None','Severe','Mild','Moderate'])
#       2 confusion.fit(X_treinamento, y_treinamento)
#       3 confusion.score(X_test,y_teste)
#
# File ~/Git/learning/ia/.ia_venv/lib/python3.12/site-packages/yellowbrick/classifier/confusion_matrix.py:150, in ConfusionMatrix.__init__(self, estimator, ax, sample_weight, percent, classes, encoder, cmap, fontsize, is_fitted, force_model, **kwargs)
#     136 def __init__(
#     137     self,
#     138     estimator,
#    (...)    148     **kwargs
#     149 ):
# --> 150     super(ConfusionMatrix, self).__init__(
#     151         estimator,
#     152         ax=ax,
#     153         classes=classes,
#     154         encoder=encoder,
#     155         is_fitted=is_fitted,
#     156         force_model=force_model,
#     157         **kwargs
#     158     )
#     160     # Visual parameters
#     161     self.fontsize = fontsize
#
# File ~/Git/learning/ia/.ia_venv/lib/python3.12/site-packages/yellowbrick/classifier/base.py:122, in ClassificationScoreVisualizer.__init__(self, estimator, ax, fig, classes, encoder, is_fitted, force_model, **kwargs)
#     109 def __init__(
#     110     self,
#     111     estimator,
#    (...)    119 ):
#     120     # A bit of type checking
#     121     if not force_model and not isclassifier(estimator):
# --> 122         raise YellowbrickTypeError(
#     123             "This estimator is not a classifier; "
#     124             "try a regression or clustering score visualizer instead!"
#     125         )
#     127     # Initialize the super method.
#     128     super(ClassificationScoreVisualizer, self).__init__(
#     129         estimator, ax=ax, fig=fig, is_fitted=is_fitted, **kwargs
#     130     )
#
# YellowbrickTypeError: This estimator is not a classifier; try a regression or clustering score visualizer instead!
